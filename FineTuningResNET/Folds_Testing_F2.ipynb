# %%
import numpy as np
import os
import time
from resnet50 import ResNet50
from keras.preprocessing import image
from keras.layers import GlobalAveragePooling2D, Dense, Dropout,Activation,Flatten

from imagenet_utils import preprocess_input
from keras.layers import Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
from sklearn.cross_validation import train_test_split
# Out:
# Using TensorFlow backend.
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Loading the training data

# %%
PATH = '/home/lenovo/DL Lab2018 PhD/Phase_2_Work/K_fold_Fish_DataSet/'

# %% [markdown]
# ### Paths to 4 Folds

# %%
fold_1_path = PATH + 'fold_1/'
fold_2_path = PATH + 'fold_2/'
fold_3_path = PATH + 'fold_3/'
fold_4_path = PATH + 'fold_4/'

# %% [markdown]
# ### Define Data_path for FOLD_1

# %%
data_path = fold_1_path
data_dir_list = os.listdir(data_path)

# %%
img_data_list=[]
F_1_labels = []
count = 0
for dataset in data_dir_list:
	img_list=os.listdir(data_path+'/'+ dataset)
	print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
	for img in img_list:
		img_path = data_path + '/'+ dataset + '/'+ img 
		img = image.load_img(img_path, target_size=(224, 224))
		x = image.img_to_array(img)
		x = np.expand_dims(x, axis=0)
		x = preprocess_input(x)
		print('Input image shape:', x.shape)
		img_data_list.append(x)
		print(count)
		F_1_labels.append(count)
	count=count+1

img_data = np.array(img_data_list)
#img_data = img_data.astype('float32')
print (img_data.shape)
img_data=np.rollaxis(img_data,1,0)
print (img_data.shape)
F_1_img_data=img_data[0]
print (F_1_img_data.shape)
# Out:
# Loaded the images of dataset-fish_20
#
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Loaded the images of dataset-fish_10
#
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# ...

# %%
F_1_img_data.shape
# Out:
# (3588, 224, 224, 3)

# %%
F1_labels= np.array(F_1_labels)
F1_labels.shape
# Out:
# (3588,)

# %% [markdown]
# ### Define Data_path for FOLD_2

# %%
data_path = fold_2_path
data_dir_list = os.listdir(data_path)

# %%
img_data_list=[]
F_2_labels = []
count = 0
for dataset in data_dir_list:
	img_list=os.listdir(data_path+'/'+ dataset)
	print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
	for img in img_list:
		img_path = data_path + '/'+ dataset + '/'+ img 
		img = image.load_img(img_path, target_size=(224, 224))
		x = image.img_to_array(img)
		x = np.expand_dims(x, axis=0)
		x = preprocess_input(x)
		print('Input image shape:', x.shape)
		img_data_list.append(x)
		print(count)
		F_2_labels.append(count)
	count=count+1

img_data = np.array(img_data_list)
#img_data = img_data.astype('float32')
print (img_data.shape)
img_data=np.rollaxis(img_data,1,0)
print (img_data.shape)
F_2_img_data=img_data[0]
print (F_2_img_data.shape)
# Out:
# Loaded the images of dataset-fish_20
#
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Loaded the images of dataset-fish_10
#
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# ...

# %%
F_2_img_data.shape
# Out:
# (3609, 224, 224, 3)

# %%
F2_labels= np.array(F_2_labels)
F2_labels.shape
# Out:
# (3609,)

# %% [markdown]
# ### Define Data_path for FOLD_3

# %%
data_path = fold_3_path
data_dir_list = os.listdir(data_path)

# %%
img_data_list=[]
F_3_labels = []
count = 0
for dataset in data_dir_list:
	img_list=os.listdir(data_path+'/'+ dataset)
	print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
	for img in img_list:
		img_path = data_path + '/'+ dataset + '/'+ img 
		img = image.load_img(img_path, target_size=(224, 224))
		x = image.img_to_array(img)
		x = np.expand_dims(x, axis=0)
		x = preprocess_input(x)
		print('Input image shape:', x.shape)
		img_data_list.append(x)
		print(count)
		F_3_labels.append(count)
	count=count+1

img_data = np.array(img_data_list)
#img_data = img_data.astype('float32')
print (img_data.shape)
img_data=np.rollaxis(img_data,1,0)
print (img_data.shape)
F_3_img_data=img_data[0]
print (F_3_img_data.shape)
# Out:
# Loaded the images of dataset-fish_20
#
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Loaded the images of dataset-fish_10
#
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# ...

# %%
F_3_img_data.shape
# Out:
# (3600, 224, 224, 3)

# %%
F3_labels= np.array(F_3_labels)
F3_labels.shape
# Out:
# (3600,)

# %% [markdown]
# ### Define Data_path for FOLD_4

# %%
data_path = fold_4_path
data_dir_list = os.listdir(data_path)

# %%
img_data_list=[]
F_4_labels = []
count = 0
for dataset in data_dir_list:
	img_list=os.listdir(data_path+'/'+ dataset)
	print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
	for img in img_list:
		img_path = data_path + '/'+ dataset + '/'+ img 
		img = image.load_img(img_path, target_size=(224, 224))
		x = image.img_to_array(img)
		x = np.expand_dims(x, axis=0)
		x = preprocess_input(x)
		print('Input image shape:', x.shape)
		img_data_list.append(x)
		print(count)
		F_4_labels.append(count)
	count=count+1

img_data = np.array(img_data_list)
#img_data = img_data.astype('float32')
print (img_data.shape)
img_data=np.rollaxis(img_data,1,0)
print (img_data.shape)
F_4_img_data=img_data[0]
print (F_4_img_data.shape)
# Out:
# Loaded the images of dataset-fish_20
#
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Input image shape: (1, 224, 224, 3)
# 0
# Loaded the images of dataset-fish_10
#
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# Input image shape: (1, 224, 224, 3)
# 1
# ...

# %%
F_4_img_data.shape
# Out:
# (3592, 224, 224, 3)

# %%
F4_labels= np.array(F_4_labels)
F4_labels.shape
# Out:
# (3592,)

# %% [markdown]
# ### Saving Features and Labels to Files

# %% [markdown]
# import pickle

# %% [markdown]
# folder_path = '/home/lenovo/DL Lab2018 PhD/Phase_2_Work/Fish_Siva_Features/'

# %% [markdown]
# ### Fold_1 Saving

# %% [markdown]
# with open(folder_path + 'Fold_1/F_1_labels'+'.csv',mode='wb') as fp:
#     pickle.dump(F1_labels,fp)
#
# with open(folder_path +'Fold_1/F_1__features'+'.csv',mode='wb') as fp:
#     pickle.dump(F_1_img_data,fp)

# %% [markdown]
# ### Fold_2 Saving

# %% [markdown]
# with open(folder_path + 'Fold_2/F_2_labels'+'.csv',mode='wb') as fp:
#     pickle.dump(F2_labels,fp)
#
# with open(folder_path +'Fold_2/F_2__features'+'.csv',mode='wb') as fp:
#     pickle.dump(F_2_img_data,fp)

# %% [markdown]
# ### Fold_3 Saving

# %% [markdown]
# with open(folder_path + 'Fold_3/F_3_labels'+'.csv',mode='wb') as fp:
#     pickle.dump(F3_labels,fp)
#
# with open(folder_path +'Fold_3/F_3_features'+'.csv',mode='wb') as fp:
#     pickle.dump(F_3_img_data,fp)

# %% [markdown]
# ### Fold_4 Saving

# %% [markdown]
# with open(folder_path + 'Fold_4/F_4_labels'+'.csv',mode='wb') as fp:
#     pickle.dump(F4_labels,fp)
#
# with open(folder_path +'Fold_4/F_4_features'+'.csv',mode='wb') as fp:
#     pickle.dump(F_4_img_data,fp)

# %% [markdown]
# # Define the number of classes

# %%
num_classes = 23

# %% [markdown]
# ## convert class labels to on-hot encoding for 4_Folds

# %%
F1_Y = np_utils.to_categorical(F1_labels, num_classes)
F2_Y = np_utils.to_categorical(F2_labels, num_classes)
F3_Y = np_utils.to_categorical(F3_labels, num_classes)
F4_Y = np_utils.to_categorical(F4_labels, num_classes)

# %% [markdown]
# ## Shuffle the dataset

# %% [markdown]
# x,y = shuffle(img_data,Y, random_state=2)

# %% [markdown]
# ## Split the dataset

# %% [markdown]
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=2)

# %% [markdown]
# # Custom_resnet_model_1
# ### Training the classifier alone with Fold_1

# %%
image_input = Input(shape=(224, 224, 3))

model = ResNet50(input_tensor=image_input, include_top=True,weights='imagenet')
#model.summary()

# %%
last_layer = model.get_layer('avg_pool').output
x= Flatten(name='flatten')(last_layer)
out = Dense(num_classes, activation='softmax', name='output_layer')(x)
custom_resnet_model = Model(inputs=image_input,outputs= out)

for layer in custom_resnet_model.layers[:-1]:
	layer.trainable = False

custom_resnet_model.layers[-1].trainable
custom_resnet_model.summary()
custom_resnet_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

t=time.time()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %% [markdown]
# ## Training with Fold_1 features & target Labels

# %%
hist = custom_resnet_model.train_on_batch(F_1_img_data, F1_Y)
print('Training time: %s' % (t - time.time()))
#(loss, accuracy) = custom_resnet_model.evaluate(X_test, y_test, batch_size=10, verbose=1)
# Out:
# Training time: -2529.382013320923

# %%
(loss, accuracy) = custom_resnet_model.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=2.5536, accuracy: 20.1718%

# %%
(loss, accuracy) = custom_resnet_model.test_on_batch(F_4_img_data, F4_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=2.5262, accuracy: 22.4666%

# %% [markdown]
# ## Training with Fold_4 features & target Labels

# %%
hist = custom_resnet_model.train_on_batch(F_4_img_data, F4_Y)
print('Training time: %s' % (t - time.time()))
# Out:
# Training time: -3750.571400642395

# %%
(loss, accuracy) = custom_resnet_model.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=2.4035, accuracy: 24.7773%

# %% [markdown]
# ## Training with Fold_3 features & target Labels

# %%
hist = custom_resnet_model.train_on_batch(F_3_img_data, F3_Y)
print('Training time: %s' % (t - time.time()))
# Out:
# Training time: -4317.024572134018

# %% [markdown]
# ## Testing with 0.25 test 2nd_Fold

# %%
(loss, accuracy) = custom_resnet_model.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=2.2715, accuracy: 27.1715%

# %% [markdown]
# ## Saving Model and weights

# %%
custom_resnet_model.save('Fish_23_Class_ResNet50_Model.h5')

# %% [markdown]
# ## To Load the Model
#     - To Load the Saved Model use the Code below

# %% [markdown]
# new_model = load_model('Fish_23_Class_ResNet50_Model.h5')

# %% [markdown]
# ******* Till Above only Worked *******

# %% [markdown]
# # Fine tune the resnet 50

# %%
model = ResNet50(weights='imagenet',include_top=False)
model.summary()
last_layer = model.output
# add a global spatial average pooling layer
x = GlobalAveragePooling2D()(last_layer)
# add fully-connected & dropout layers
x = Dense(512, activation='relu',name='fc-1')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu',name='fc-2')(x)
x = Dropout(0.5)(x)
# a softmax layer for 4 classes
out = Dense(num_classes, activation='softmax',name='output_layer')(x)

# this is the model we will train
custom_resnet_model2 = Model(inputs=model.input, outputs=out)



for layer in custom_resnet_model2.layers[:-6]:
	layer.trainable = False

custom_resnet_model2.layers[-1].trainable
custom_resnet_model2.summary()
custom_resnet_model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

t=time.time()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# ...

# %% [markdown]
# ### Training with Folds 1_4_&_3 DataSets with Changed_Model

# %%
hist_New = custom_resnet_model2.train_on_batch(F_1_img_data, F1_Y)
print('Training time: %s' % (t - time.time()))
# Out:
# Training time: -296.3654959201813

# %%
(loss, accuracy) = custom_resnet_model2.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=2.8036, accuracy: 25.6403%

# %%
hist_New = custom_resnet_model2.train_on_batch(F_4_img_data, F4_Y)
print('Training time: %s' % (t - time.time()))
# Out:
# Training time: -916.3964169025421

# %%
(loss, accuracy) = custom_resnet_model2.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=1.9987, accuracy: 45.0445%

# %%
hist_New = custom_resnet_model2.train_on_batch(F_3_img_data, F3_Y)
print('Training time: %s' % (t - time.time()))

# %%
(loss, accuracy) = custom_resnet_model2.test_on_batch(F_2_img_data, F2_Y)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss,accuracy * 100))
# Out:
# [INFO] loss=1.8347, accuracy: 49.8051%

# %% [markdown]
# ### Saving New_Model2

# %% [markdown]
# custom_resnet_model2.save('Fish_23_Class_ResNet52_Model2.h5')

# %% [markdown]
# ## Plotting The Accuracies

# %% [markdown]
# import matplotlib.pyplot as plt
# ##### visualizing losses and accuracy
# train_loss=hist.history['loss']
# val_loss=hist.history['val_loss']
# train_acc=hist.history['acc']
# val_acc=hist.history['val_acc']
# xc=range(12)
#
# plt.figure(1,figsize=(7,5))
# plt.plot(xc,train_loss)
# plt.plot(xc,val_loss)
# plt.xlabel('num of Epochs')
# plt.ylabel('loss')
# plt.title('train_loss vs val_loss')
# plt.grid(True)
# plt.legend(['train','val'])
# #print plt.style.available # use bmh, classic,ggplot for big pictures
# plt.style.use(['classic'])
#
# plt.figure(2,figsize=(7,5))
# plt.plot(xc,train_acc)
# plt.plot(xc,val_acc)
# plt.xlabel('num of Epochs')
# plt.ylabel('accuracy')
# plt.title('train_acc vs val_acc')
# plt.grid(True)
# plt.legend(['train','val'],loc=4)
# #print plt.style.available # use bmh, classic,ggplot for big pictures
# plt.style.use(['classic'])
